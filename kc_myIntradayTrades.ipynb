# %% [markdown]
# <a href="https://colab.research.google.com/github/anvy87/AlgoTrading/blob/master/kc_myIntradayTrades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kiteconnect
# Out:
# Collecting kiteconnect
#   Downloading kiteconnect-5.0.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting service-identity>=18.1.0 (from kiteconnect)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from kiteconnect) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from kiteconnect) (1.17.0)
# Requirement already satisfied: pyOpenSSL>=17.5.0 in /usr/local/lib/python3.12/dist-packages (from kiteconnect) (24.2.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from kiteconnect) (2.9.0.post0)
# Collecting autobahn==19.11.2 (from autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading autobahn-19.11.2-py2.py3-none-any.whl.metadata (16 kB)
# Collecting txaio>=18.8.1 (from autobahn==19.11.2->autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading txaio-25.6.1-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cryptography>=2.7 in /usr/local/lib/python3.12/dist-packages (from autobahn==19.11.2->autobahn[twisted]==19.11.2->kiteconnect) (43.0.3)
# Collecting zope.interface>=3.6.0 (from autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading zope.interface-7.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.9 MB/s eta 0:00:00
# Collecting Twisted>=12.1.0 (from autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading twisted-25.5.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->kiteconnect) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->kiteconnect) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->kiteconnect) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->kiteconnect) (2025.8.3)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->kiteconnect) (25.3.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->kiteconnect) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->kiteconnect) (0.4.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.7->autobahn==19.11.2->autobahn[twisted]==19.11.2->kiteconnect) (1.17.1)
# Collecting automat>=24.8.0 (from Twisted>=12.1.0->autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from Twisted>=12.1.0->autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=12.1.0->autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from Twisted>=12.1.0->autobahn[twisted]==19.11.2->kiteconnect)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from Twisted>=12.1.0->autobahn[twisted]==19.11.2->kiteconnect) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from zope.interface>=3.6.0->autobahn[twisted]==19.11.2->kiteconnect) (75.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.7->autobahn==19.11.2->autobahn[twisted]==19.11.2->kiteconnect) (2.22)
# Downloading kiteconnect-5.0.1-py3-none-any.whl (24 kB)
# Downloading autobahn-19.11.2-py2.py3-none-any.whl (771 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.5/771.5 kB 12.1 MB/s eta 0:00:00
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading twisted-25.5.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.0 MB/s eta 0:00:00
# Downloading txaio-25.6.1-py2.py3-none-any.whl (31 kB)
# Downloading zope.interface-7.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 20.9 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 4.0 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.8 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Installing collected packages: zope.interface, txaio, incremental, hyperlink, constantly, automat, Twisted, service-identity, autobahn, kiteconnect
# Successfully installed Twisted-25.5.0 autobahn-19.11.2 automat-25.4.16 constantly-23.10.4 hyperlink-21.0.0 incremental-24.7.2 kiteconnect-5.0.1 service-identity-24.2.0 txaio-25.6.1 zope.interface-7.2

# %%
from kiteconnect import KiteConnect
import pandas as pd
import numpy as np
import logging
import os
import time
import datetime as dt
api_key = "1ll4p8ziqlk8hh7g"
api_secret = "x59r5u1vd25annfpgts22wv8ykfueirl"
kite = KiteConnect(api_key=api_key)

# %%
print(kite.login_url()) #use this url to manually login and authorize yourself
# Out:
# https://kite.zerodha.com/connect/login?api_key=1ll4p8ziqlk8hh7g&v=3

# %%
#generate trading session
request_token = "5v66FBq5BtyymvPf0AKbnGNQT6Vqbk04" #Extract request token from the redirect url obtained after you authorize yourself by loggin in
data = kite.generate_session(request_token, api_secret=api_secret)
#create kite trading object
kite.set_access_token(data["access_token"])

# %%
#get dump of all NSE instruments
instrument_dump = kite.instruments("NSE")
instrument_df = pd.DataFrame(instrument_dump)
instrument_df.to_csv("NSE_Instruments.csv",index=False)

# %%
def instrumentLookup(instrument_df,symbol):
    """Looks up instrument token for a given script from instrument dump"""
    try:
        return instrument_df[instrument_df.tradingsymbol==symbol].instrument_token.values[0]
    except:
        return -1

# %%
def fetchOHLC(ticker,interval,duration):
  """extracts historcial data and outputs in the form of dataframe"""
  instrument = instrumentLookup(instrument_df,ticker)
  data = pd.DataFrame(kite.historical_data(instrument,dt.date.today()-dt.timedelta(duration),dt.date.today(),interval))
  data.set_index("date",inplace=True)
  return data

# %%
orders = kite.orders()
for order in orders:
    print(order["tradingsymbol"], order["transaction_type"], order["quantity"], order["average_price"], order["order_timestamp"])
# Out:
# RELIANCE SELL 35 1421 2025-08-20 11:00:03
# HDFCBANK BUY 25 1979.9 2025-08-20 11:00:05
# BHARTIARTL SELL 25 1930.9 2025-08-20 11:00:05
# TCS SELL 15 3049 2025-08-20 11:00:06
# ICICIBANK SELL 35 1426.9 2025-08-20 11:00:07
# SBIN SELL 60 829.15 2025-08-20 11:00:08
# INFY SELL 30 1478.6 2025-08-20 11:00:09
# HINDUNILVR SELL 15 2649.7 2025-08-20 11:00:10
# BAJFINANCE SELL 55 887.5827272727272 2025-08-20 11:00:11
# ITC SELL 120 408.95 2025-08-20 11:00:11
# HDFCBANK SELL 25 1989.4000000000003 2025-08-20 14:58:16
# SBIN BUY 60 829.3 2025-08-20 14:58:52
# ITC BUY 120 406.65 2025-08-20 14:59:15
# BHARTIARTL BUY 25 1930 2025-08-20 14:59:25
# TCS BUY 15 3097.4 2025-08-20 15:19:06
# RELIANCE BUY 35 1412 2025-08-20 15:19:11
# INFY BUY 30 1495.6 2025-08-20 15:19:16
# ICICIBANK BUY 35 1430.6 2025-08-20 15:19:21
# HINDUNILVR BUY 15 2664.8 2025-08-20 15:19:26
# BAJFINANCE BUY 55 887.35 2025-08-20 15:19:30

# %%
kite.orders()["tradingsymbol"]
# Out:
# [{'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038801129676800',
#   'exchange_order_id': '1300000020672996',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 3),
#   'exchange_update_timestamp': '2025-08-20 11:00:03',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 3),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'RELIANCE',
#   'instrument_token': 738561,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 35,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1421,
#   'filled_quantity': 35,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038808167718912',
#   'exchange_order_id': '1100000027493636',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 5),
#   'exchange_update_timestamp': '2025-08-20 11:00:05',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 5),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'HDFCBANK',
#   'instrument_token': 341249,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 25,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1979.9,
#   'filled_quantity': 25,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038811728683008',
#   'exchange_order_id': '1000000019797331',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 5),
#   'exchange_update_timestamp': '2025-08-20 11:00:05',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 5),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'BHARTIARTL',
#   'instrument_token': 2714625,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 25,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1930.9,
#   'filled_quantity': 25,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038815214149632',
#   'exchange_order_id': '1300000020681774',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 6),
#   'exchange_update_timestamp': '2025-08-20 11:00:06',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 6),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'TCS',
#   'instrument_token': 2953217,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 15,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 3049,
#   'filled_quantity': 15,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038819085492224',
#   'exchange_order_id': '1100000027501674',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 7),
#   'exchange_update_timestamp': '2025-08-20 11:00:07',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 7),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'ICICIBANK',
#   'instrument_token': 1270529,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 35,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1426.9,
#   'filled_quantity': 35,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038822562570240',
#   'exchange_order_id': '1300000020685602',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 8),
#   'exchange_update_timestamp': '2025-08-20 11:00:08',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 8),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'SBIN',
#   'instrument_token': 779521,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 60,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 829.15,
#   'filled_quantity': 60,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038825980928000',
#   'exchange_order_id': '1100000027507015',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 9),
#   'exchange_update_timestamp': '2025-08-20 11:00:09',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 9),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'INFY',
#   'instrument_token': 408065,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 30,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1478.6,
#   'filled_quantity': 30,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038829520920576',
#   'exchange_order_id': '1100000027510296',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 10),
#   'exchange_update_timestamp': '2025-08-20 11:00:10',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 10),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'HINDUNILVR',
#   'instrument_token': 356865,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 15,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 2649.7,
#   'filled_quantity': 15,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038833065107456',
#   'exchange_order_id': '1000000019809534',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 11),
#   'exchange_update_timestamp': '2025-08-20 11:00:11',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 11),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'BAJFINANCE',
#   'instrument_token': 81153,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 55,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 887.5827272727272,
#   'filled_quantity': 55,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '111111111111100',
#   'order_id': '1958038836621877248',
#   'exchange_order_id': '1100000027516115',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 11),
#   'exchange_update_timestamp': '2025-08-20 11:00:11',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 11, 0, 11),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'ITC',
#   'instrument_token': 424961,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 120,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 408.95,
#   'filled_quantity': 120,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":169553,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958098750824259584',
#   'exchange_order_id': '1100000065341900',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 14, 58, 16),
#   'exchange_update_timestamp': '2025-08-20 14:58:16',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 14, 58, 16),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'HDFCBANK',
#   'instrument_token': 341249,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 25,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1989.4000000000003,
#   'filled_quantity': 25,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958098902574178304',
#   'exchange_order_id': '1300000051021696',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 14, 58, 52),
#   'exchange_update_timestamp': '2025-08-20 14:58:52',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 14, 58, 52),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'SBIN',
#   'instrument_token': 779521,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 60,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 829.3,
#   'filled_quantity': 60,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958098999038976000',
#   'exchange_order_id': '1100000065520241',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 14, 59, 15),
#   'exchange_update_timestamp': '2025-08-20 14:59:15',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 14, 59, 15),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'ITC',
#   'instrument_token': 424961,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 120,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 406.65,
#   'filled_quantity': 120,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958099038712897536',
#   'exchange_order_id': '1000000049411682',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 14, 59, 25),
#   'exchange_update_timestamp': '2025-08-20 14:59:25',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 14, 59, 25),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'BHARTIARTL',
#   'instrument_token': 2714625,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 25,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1930,
#   'filled_quantity': 25,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958103994207576064',
#   'exchange_order_id': '1300000054133656',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 6),
#   'exchange_update_timestamp': '2025-08-20 15:19:06',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 6),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'TCS',
#   'instrument_token': 2953217,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 15,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 3097.4,
#   'filled_quantity': 15,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958104014344429568',
#   'exchange_order_id': '1300000054148956',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 11),
#   'exchange_update_timestamp': '2025-08-20 15:19:11',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 11),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'RELIANCE',
#   'instrument_token': 738561,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 35,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1412,
#   'filled_quantity': 35,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958104033659199488',
#   'exchange_order_id': '1100000069366844',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 16),
#   'exchange_update_timestamp': '2025-08-20 15:19:16',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 16),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'INFY',
#   'instrument_token': 408065,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 30,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1495.6,
#   'filled_quantity': 30,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958104055876427776',
#   'exchange_order_id': '1100000069383187',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 21),
#   'exchange_update_timestamp': '2025-08-20 15:19:21',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 21),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'ICICIBANK',
#   'instrument_token': 1270529,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 35,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 1430.6,
#   'filled_quantity': 35,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958104076193636352',
#   'exchange_order_id': '1100000069400211',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 26),
#   'exchange_update_timestamp': '2025-08-20 15:19:26',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 26),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'HINDUNILVR',
#   'instrument_token': 356865,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 15,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 2664.8,
#   'filled_quantity': 15,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None},
#  {'account_id': 'YX0162',
#   'placed_by': 'YX0162',
#   'terminal_id': '333333333333100',
#   'order_id': '1958104095084781568',
#   'exchange_order_id': '1000000052081156',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 30),
#   'exchange_update_timestamp': '2025-08-20 15:19:30',
#   'exchange_timestamp': datetime.datetime(2025, 8, 20, 15, 19, 30),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'NSE',
#   'tradingsymbol': 'BAJFINANCE',
#   'instrument_token': 81153,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'MIS',
#   'quantity': 55,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 887.35,
#   'filled_quantity': 55,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'meta_raw': '{"tag":"","tags":null,"app_id":19,"gttp":null,"iceberg":{"leg":0,"legs":0,"leg_quantity":0,"total_quantity":0,"remaining_quantity":0},"validity_ttl":0,"aucno":"","kite_order_id":"","_kite":{"user":{"silo":"i","poa":"ddpi","twofa_type":"sms"},"silo":"i"}}',
#   'tag': None,
#   'guid': None}]

# %%
# List of Nifty 50 constituent trading symbols (update as per latest list)
nifty50_symbols = ["RELIANCE", "HDFCBANK", "BHARTIARTL", "TCS", "ICICIBANK", "SBIN", "INFY", "HINDUNILVR", "BAJFINANCE", "ITC"]

# %%
instrument_token = [6401, 40193, 60417, 81153, 98049, 119553, 177665, 225537, 315393, 341249, 345089, 348929, 408065, 424961, 492033, 502785, 519937,
 633601, 738561, 779521, 857857, 878593, 884737, 895745, 897537, 969473, 1270529, 1304833, 1346049, 1510401, 1850625, 2815745, 2939649,
 2952193, 2953217, 2977281, 3001089, 3465729, 4267265, 4268801, 4598529, 4644609, 5215745, 5582849, 3861249]

# %% [markdown]
# # **placing order**

# %%
def placeMarketOrder(symbol, buy_sell, quantity):
  # place intraday market order on NSE
  if buy_sell == "buy":
    t_type = kite.TRANSACTION_TYPE_BUY
  elif buy_sell == "sell":
    t_type = kite.TRANSACTION_TYPE_SELL
  kite.place_order(tradingsymbol=symbol,
                   exchange=kite.EXCHANGE_NSE,
                   transaction_type=t_type,
                   quantity=5*quantity, # 5x leverage
                   order_type=kite.ORDER_TYPE_MARKET,
                   product=kite.PRODUCT_MIS,
                   variety=kite.VARIETY_AMO)
